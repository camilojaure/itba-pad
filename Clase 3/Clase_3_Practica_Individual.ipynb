# %% [markdown]
# # Clase 3 — Práctica Individual
# ## Tu turno: segmentar y leer el tiempo
# ### Maestría en Fintech · ITBA · 2026
#
# ---
#
# Mismo dataset que la práctica guiada: ~29.000 transacciones de 2024. **Preguntas nuevas.**
#
# Ninguna está resuelta en la guiada, pero todas se responden con las mismas herramientas:
# `groupby`, `.agg()`, `pivot_table`, `pd.to_datetime`, `resample` y `rolling`.

# %% [markdown]
# ---
# ## ⚠️ Paso cero: hacé tu propia copia
#
# **No escribas en esta notebook.** Es el original del curso.
#
# 1. Menú **`Archivo`** → **`Guardar una copia en Drive`**
# 2. Se abre una pestaña nueva — **esa es tuya**
# 3. Renombrala haciendo clic en el título: **`Clase3_Individual_TuNombre`**
# 4. Cerrá esta pestaña y trabajá en la tuya

# %% [markdown]
# ---
# ## Cómo se trabaja acá
#
# **Una pregunta por vez.** Escribí, ejecutá, mirá el resultado, y recién ahí seguí.
#
# **Cada respuesta termina con una lectura de negocio**, en la celda `**Lectura:**` de abajo. Un número solo no es una respuesta.
#
# **Gemini es tu copiloto, no tu piloto.** Pedile sintaxis y que te explique errores. No le pidas criterio ni conclusiones.
#
# **Un prompt útil tiene cuatro partes** — contexto, datos, qué querés, cómo lo querés ver:
#
# > *"Tengo un DataFrame de pandas llamado `df` con las columnas `fecha` (datetime), `categoria` y `monto_ars`.
# > Calculá el gasto total por mes solo para la categoría 'Viajes' y mostralo en un gráfico de línea con marcadores."*
#
# Y siempre: **leé el código antes de ejecutarlo.**

# %% [markdown]
# ---
# ## Setup
#
# Ejecutá esta celda primero. Carga las librerías, el dataset, y **ya convierte la fecha** y agrega mes, trimestre y día de la semana.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (11, 5)

DATOS = 'https://raw.githubusercontent.com/camilojaure/itba-pad/main/datasets/'
df = pd.read_csv(DATOS + 'transacciones.csv')

df['fecha'] = pd.to_datetime(df['fecha'])
df['mes'] = df['fecha'].dt.month
df['trimestre'] = df['fecha'].dt.quarter
df['dia_semana'] = df['fecha'].dt.day_name()

print(f'{len(df):,} transacciones cargadas')
df.head()

# %% [markdown]
# ---
# ## Ejercicio 1 · Calentamiento: débito vs crédito
#
# ¿Cuál es el **ticket promedio y el ticket mediano** de cada `tipo` de tarjeta? Sumá también la cantidad de transacciones.
#
# *Pista: agrupar por `tipo` y usar `.agg()` con tres métricas.*

# %%
# Tu código acá

# %% [markdown]
# **Lectura:** *¿Con qué tipo se hacen las compras más grandes? ¿Por qué te parece que pasa eso?*
#
# > _(escribí tu respuesta acá)_

# %% [markdown]
# ---
# ## Ejercicio 2 · ¿Qué día se gasta más?
#
# Calculá el **gasto total por día de la semana** y mostralo en un gráfico de barras, **ordenado de lunes a domingo** (no alfabéticamente).
#
# *Pista: `day_name()` devuelve los días en inglés. Para ordenarlos, pedile a Gemini cómo usar `.reindex()` con una lista de días.*

# %%
# Tu código acá

# %% [markdown]
# **Lectura:** *Si tuvieras que elegir dos días para lanzar una promoción, ¿cuáles serían? ¿Y cuándo reforzarías la capacidad de procesamiento?*
#
# > _(escribí tu respuesta acá)_

# %% [markdown]
# ---
# ## Ejercicio 3 · Pivot: el ticket en el tiempo
#
# Armá una `pivot_table` con el **ticket promedio** (`mean` de `monto_ars`) por `categoria` (filas) y `trimestre` (columnas). Mostrala como heatmap con `sns.heatmap`.
#
# *Pista: dividí por 1.000 antes de graficar para leer en miles.*

# %%
# Tu código acá

# %% [markdown]
# **Lectura:** *¿El ticket sube en todas las categorías de Q1 a Q4? ¿Eso significa que la gente compra más, o que las cosas cuestan más?*
#
# > _(escribí tu respuesta acá)_

# %% [markdown]
# ---
# ## Ejercicio 4 · Rechazos: ¿cuántos o qué proporción?
#
# Calculá, **por mes**, la cantidad de transacciones rechazadas (`aprobada == 0`) y la **tasa de rechazo** (rechazadas / total). Graficá la tasa como serie de tiempo.
#
# *Pista: `aprobada` es 0/1. Acordate del truco de la Clase 2: el promedio de una columna 0/1 es una proporción. La tasa de rechazo es `1 - promedio de aprobada`.*

# %%
# Tu código acá

# %% [markdown]
# **Lectura:** *¿Hay algún mes que se despegue? ¿Mirar solo la cantidad absoluta te habría contado la misma historia? ¿Qué le preguntarías al equipo de operaciones?*
#
# > _(escribí tu respuesta acá)_

# %% [markdown]
# ---
# ## Ejercicio 5 · ¿Qué categoría creció más?
#
# Para cada categoría, calculá el crecimiento **del Q1 al Q4** en dos métricas: **monto** y **cantidad de transacciones**. Ordená por crecimiento de monto.
#
# *Pista: una `pivot_table` con trimestres en columnas, y después `(Q4 / Q1 - 1) * 100`.*

# %%
# Tu código acá

# %% [markdown]
# **Lectura:** *¿Cuál creció más? Compará el crecimiento en monto contra el de cantidad: ¿en qué categorías el crecimiento es casi todo precio? ¿Cuál crece de verdad?*
#
# > _(escribí tu respuesta acá)_

# %% [markdown]
# ---
# ## Ejercicio 6 · Tendencia de 6 meses
#
# Armá la serie de **gasto total mensual** y calculá su **promedio móvil de 6 meses**. Graficá las dos líneas juntas.

# %%
# Tu código acá

# %% [markdown]
# **Lectura:** *¿En qué mes aparece el primer valor de la media móvil, y por qué? ¿La caída de agosto–septiembre se ve en la tendencia?*
#
# > _(escribí tu respuesta acá)_

# %% [markdown]
# ---
# ## Ejercicio 7 · ¿Cuánto pesa cada categoría?
#
# ¿Qué **porcentaje del gasto total** representa cada categoría? Mostralo en un gráfico de **barras horizontales** ordenado.
#
# *Opcional: hacé también la torta (`plt.pie`) y compará cuál se lee mejor.*

# %%
# Tu código acá

# %% [markdown]
# **Lectura:** *¿Cuánto concentran las 3 primeras? ¿Con 10 categorías, qué gráfico comunica mejor: la torta o las barras?*
#
# > _(escribí tu respuesta acá)_

# %% [markdown]
# ---
# ## Ejercicio 8 · ¿Viajes tiene estacionalidad?
#
# Filtrá solo `Viajes` y armá su evolución mensual en **monto** y en **cantidad** de transacciones. Graficalas.
#
# *Pista: primero filtrás, después hacés `resample`. Dos pasos, no uno.*

# %%
# Tu código acá

# %% [markdown]
# **Lectura:** *¿En qué meses están los picos? ¿Coinciden con el calendario argentino que vimos en la teoría? ¿Aparece todo lo que esperabas? Con un solo año de datos, ¿podés afirmar que es estacionalidad?*
#
# > _(escribí tu respuesta acá)_

# %% [markdown]
# ---
# ## Ejercicio 9 · El cliente típico
#
# Calculá el **ticket promedio por cliente, por mes**: primero el ticket promedio de cada cliente en cada mes, y después el promedio de esos valores para cada mes.
#
# Compará el resultado con `df.groupby('mes')['monto_ars'].mean()`.
#
# *Pista: `groupby(['cliente_id', 'mes'])` → `.mean()` → y después agrupar ese resultado por mes.*

# %%
# Tu código acá

# %% [markdown]
# **Lectura:** *¿Por qué los dos números no dan igual? ¿Cuál usarías para responder "cuánto gasta un cliente típico por compra"?*
#
# > _(escribí tu respuesta acá)_

# %% [markdown]
# ---
# ## Ejercicio 10 · Desafío — el resumen trimestral
#
# El director te pide **una tabla** para el comité con el año en cuatro filas. Para cada trimestre:
#
# - monto total
# - cantidad de transacciones
# - ticket promedio
# - **cantidad de clientes que operaron** (clientes distintos)
# - **categoría con más monto**
#
# Sumá la **variación del monto contra el trimestre anterior** (%).
#
# *Pistas: `.agg()` con `'nunique'` cuenta clientes distintos. Para la categoría top de cada trimestre, pedile ayuda a Gemini
# — es una agrupación por dos columnas y después quedarse con la mayor.*

# %%
# Tu código acá

# %% [markdown]
# **Tu mensaje para el comité — tres bullets, no una tabla:**
#
# 1. **El crecimiento:** _(cuánto creció el monto, y cuánto de eso es actividad real)_
# 2. **Quién lo explica:** _(qué categoría domina y cuál acelera)_
# 3. **La alerta:** _(qué pasa con la cantidad de clientes, y por qué eso importa aunque las ventas se vean bien)_
#
# > Mirá las cinco columnas juntas. Si el monto sube mientras la cantidad de clientes baja, el negocio se está concentrando.

# %% [markdown]
# ---
# ## Antes de cerrar — checklist
#
# - [ ] Estás trabajando en **tu copia**, no en el original
# - [ ] Todas las celdas corren de arriba a abajo sin errores (`Entorno de ejecución → Reiniciar y ejecutar todo`)
# - [ ] Cada ejercicio tiene su **lectura de negocio** escrita, no solo el número
# - [ ] El desafío cierra con los tres bullets para el comité
#
# ---
#
# **Si algo no salió:** anotá dónde te trabaste y traelo a la próxima clase.
#
# **Qué viene en la Clase 4:** hasta acá trabajamos con una sola tabla. ¿Qué pasa cuando la respuesta
# está repartida entre clientes, tarjetas y transacciones? **Joins.**
