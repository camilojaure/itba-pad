# %% [markdown]
# # 🎓 Clase 6 — Evaluación práctica
# **Maestría en Fintech — Programación para el Análisis de Datos**
#
# ---
#
# ## Instrucciones
#
# - Trabajás **individualmente**
# - Tenés **90 minutos**
# - Podés usar Google Colab, Gemini y tus notebooks anteriores
# - El criterio de evaluación **no es la sintaxis perfecta** — es la **calidad del análisis y la interpretación de negocio**
# - Al final de cada sección hay una pregunta de negocio que debés responder en lenguaje natural
#
# ---
#
# ## Dataset: Portafolio de Préstamos
#
# Sos analista de datos en una fintech que otorga préstamos personales, hipotecarios, automotrices, de consumo y PyME. Te pasan el portafolio actual para que hagas un diagnóstico.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 5)

# Los datos se descargan solos desde el repo del curso.
# No hace falta subir ningún archivo a Colab.
DATOS = 'https://raw.githubusercontent.com/camilojaure/itba-pad/main/datasets/'

df = pd.read_csv(DATOS + 'portafolio_prestamos.csv')
print(f'Dataset cargado: {len(df):,} préstamos')
df.head()

# %% [markdown]
# ---
# ## SECCIÓN 1 — Exploración inicial (20 pts)
#
# *Antes de cualquier análisis, necesitás entender qué tenés.*

# %%
# 1.1 Mostrá las dimensiones, tipos de datos y estadísticas descriptivas del dataset.
# Tu código acá:

# %%
# 1.2 ¿Hay valores nulos? ¿En qué columnas?
# Tu código acá:

# %%
# 1.3 ¿Cuántos préstamos hay de cada tipo? ¿Y de cada estado?
# Graficalo.
# Tu código acá:

# %% [markdown]
# > **Pregunta de negocio 1:** En 2-3 oraciones, ¿qué te dice este portafolio a primera vista? ¿Hay algo que te llame la atención?
#
# *Tu respuesta acá:*

# %% [markdown]
# ---
# ## SECCIÓN 2 — Análisis de mora (30 pts)
#
# *El estado de los préstamos es lo más crítico para el negocio.*

# %%
# 2.1 Calculá el % de préstamos en mora (cualquier estado que NO sea 'Al día' ni 'Cancelado')
# Tu código acá:

# %%
# 2.2 ¿Qué tipo de préstamo tiene mayor tasa de mora?
# Mostralo en una tabla y en un gráfico.
# Tu código acá:

# %%
# 2.3 ¿Hay diferencia en el monto otorgado entre préstamos al día y en mora?
# Mostralo con estadísticas descriptivas y un boxplot.
# Tu código acá:

# %%
# 2.4 ¿La tasa de interés es más alta en los préstamos que entraron en mora?
# Tu código acá:

# %% [markdown]
# > **Pregunta de negocio 2:** Si fueras el Chief Risk Officer, ¿qué tipo de préstamo te preocupa más y por qué? ¿Qué política cambiarías?
#
# *Tu respuesta acá:*

# %% [markdown]
# ---
# ## SECCIÓN 3 — Análisis geográfico y temporal (25 pts)

# %%
# 3.1 ¿Qué provincia tiene más volumen de préstamos otorgados (en ARS)?
# Tu código acá:

# %%
# 3.2 ¿Hay provincias con tasas de mora significativamente más altas?
# Mostralo en un gráfico.
# Tu código acá:

# %%
# 3.3 Analizá cómo evolucionó el monto total otorgado mes a mes.
# Tip: convertí 'fecha_otorgamiento' a datetime y usá resample.
# Tu código acá:

# %% [markdown]
# > **Pregunta de negocio 3:** ¿Dónde concentrarías los esfuerzos de recupero de deuda geográficamente? Justificá.
#
# *Tu respuesta acá:*

# %% [markdown]
# ---
# ## SECCIÓN 4 — Insight final (25 pts)

# %%
# 4.1 Armá una tabla resumen ejecutiva con las métricas más importantes del portafolio:
# - Monto total otorgado
# - Tasa de mora general
# - Tipo de préstamo con mayor mora
# - Provincia con mayor riesgo
# - Tasa promedio del portafolio
# Presentalo de forma clara y ordenada.
# Tu código acá:

# %%
# 4.2 Creá UNA visualización que cuente la historia más importante del portafolio.
# Puede ser el gráfico que vos consideres más relevante.
# Tu código acá:

# %% [markdown]
# ---
# ## 🎤 Conclusión ejecutiva
#
# > En máximo **5 oraciones**, resumí el estado del portafolio y tus 2-3 recomendaciones principales para el equipo de negocio.
#
# *Tu conclusión acá:*

# %% [markdown]
# ---
#
# ## Segunda parte de la clase: ¿A dónde vas desde acá?
#
# *(Esta sección se completa después del examen — es una guía de carrera)*

# %% [markdown]
# ## 🚀 Career Path: del analista al decision-maker con datos
#
# ### Lo que ya podés hacer
# ✅ Cargar y explorar datasets con Pandas
# ✅ Limpiar datos reales
# ✅ Agregar, segmentar y cruzar fuentes
# ✅ Analizar series de tiempo
# ✅ Visualizar y comunicar hallazgos
# ✅ Usar IA como copiloto
#
# ### ¿Qué sigue?
#
# | Herramienta / Skill | Para qué sirve | Por dónde empezar |
# |---------------------|----------------|-------------------|
# | **SQL** | Extraer datos de bases de datos reales | Mode Analytics SQL Tutorial (gratis) |
# | **Power BI / Tableau** | Dashboards ejecutivos | Tutorial oficial de Power BI |
# | **Estadística** | Entender si lo que ves es significativo | Curso de Khan Academy |
# | **Machine Learning básico** | Predecir churn, scoring crediticio | scikit-learn en Kaggle Learn |
# | **Git / GitHub** | Versionar tu trabajo | GitHub Skills (gratis) |
#
# ### Cómo mostrarlo en tu CV
# - Subí tus notebooks a GitHub
# - Publicá un análisis en LinkedIn con visualizaciones
# - Participá en una competencia de Kaggle (las de nivel principiante son muy accesibles)
# - Certificación de Google Data Analytics (gratuita con beca)
#
# ### El perfil que el mercado fintech está buscando
# No buscan programadores. Buscan personas que entiendan el negocio **y** puedan sacarle jugo a los datos. Eso es exactamente lo que hiciste en este curso.
